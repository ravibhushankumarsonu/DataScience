# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
Data=pd.read_csv('home_data.csv')

# %%
Data.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
Data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
Data[['bedrooms','price']].groupby('bedrooms').mean()
# Out:
#                  price
# bedrooms
# 0         4.095037e+05
# 1         3.176429e+05
# 2         4.013727e+05
# 3         4.662321e+05
# 4         6.354195e+05
# 5         7.865998e+05
# 6         8.255206e+05
# 7         9.511847e+05
# 8         1.105077e+06
# 9         8.939998e+05
# 10        8.193333e+05
# 11        5.200000e+05
# 33        6.400000e+05

# %%
plt.figure(figsize=(15,15))
sns.regplot(x='price',y='bathrooms',data=Data,color='green')
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
train,test=train_test_split(Data,test_size=0.2)

# %%
train.head()
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 8753   5103900015  20140626T000000  358000         3       1.50         2450
# 7825   6392001005  20140620T000000  511500         4       1.00         1360
# 13744  3582750120  20140715T000000  409000         2       2.25         1640
# 17275  5259800440  20140926T000000  232000         3       1.75         1290
# 16391  1393800005  20150507T000000  355000         2       1.00          900
#
#        sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 8753      12497     1.0           0     0     ...          7        2450
# 7825       6000     1.5           0     0     ...          7        1360
# 13744      2128     2.0           0     0     ...          8        1640
# 17275      6604     1.0           0     0     ...          7        1290
# 16391      6656     1.0           0     0     ...          7         900
#
# ...

# %%
test.head()
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 8527   1250202324  20150122T000000  610000         4       2.75         2640
# 16216  4331000130  20141017T000000  315000         3       2.00         1770
# 15163  2848700095  20150402T000000  412000         4       1.50         1960
# 3624   2767602141  20141222T000000  650000         3       1.50         1380
# 17674  1868900395  20140902T000000  500000         2       1.00          930
#
#        sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 8527       8400     1.0           0     2     ...          8        1440
# 16216      9685     1.0           0     0     ...          5        1770
# 15163      5000     1.0           0     0     ...          7         980
# 3624       4290     1.0           0     0     ...          7        1080
# 17674      3750     1.0           0     0     ...          7         930
#
# ...

# %% [markdown]
# Make the predication model

# %%
plt.figure(figsize=(15,15))
plt.scatter(Data['price'],Data['bathrooms'])
plt.grid()
plt.xticks(rotation=90)
plt.show()

# %%
train.head()
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 8753   5103900015  20140626T000000  358000         3       1.50         2450
# 7825   6392001005  20140620T000000  511500         4       1.00         1360
# 13744  3582750120  20140715T000000  409000         2       2.25         1640
# 17275  5259800440  20140926T000000  232000         3       1.75         1290
# 16391  1393800005  20150507T000000  355000         2       1.00          900
#
#        sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 8753      12497     1.0           0     0     ...          7        2450
# 7825       6000     1.5           0     0     ...          7        1360
# 13744      2128     2.0           0     0     ...          8        1640
# 17275      6604     1.0           0     0     ...          7        1290
# 16391      6656     1.0           0     0     ...          7         900
#
# ...

# %%
from sklearn import linear_model
#regr=linear_model.LinearRegression().fit(train['sqft_living'],train['price'])
#x=np.array(train[['sqft_living', 'bedrooms', 'bathrooms', 'floors']])
#y=np.array(train['price'])
x=train[['sqft_living', 'bedrooms', 'bathrooms', 'floors']]
y=train['price']
print(x.shape)
print(y.shape)
# Out:
# (17290, 4)
# (17290,)

# %%
#val=np.sum(x,axis=0)
#x=x/val

# %%
x.head()
# Out:
#        sqft_living  bedrooms  bathrooms  floors
# 8753          2450         3       1.50     1.0
# 7825          1360         4       1.00     1.5
# 13744         1640         2       2.25     2.0
# 17275         1290         3       1.75     1.0
# 16391          900         2       1.00     1.0

# %%
regr=linear_model.LinearRegression().fit(x,y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/linalg/basic.py:1018: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %%
regr.coef_
# Out:
# array([   313.17815918, -57377.74810072,   6802.72817052,   2233.41555687])

# %%
print(regr.score(x,y))
# Out:
# 0.508763722811

# %%
def cost(y, y_pred):
    #print(len(y))
    cost=(1/len(y))*np.sum((y_pred-y)*(y_pred-y))
    return cost

# %%
test_y=test['price']
test_x=test[['sqft_living', 'bedrooms', 'bathrooms', 'floors']]
print(regr.predict(test_x))
print(cost(test_y, regr.predict(test_x)))
# Out:
# [ 683781.50629598  463592.20978373  462316.94784162 ...,  314697.79292732
#   395274.27247207  988636.21920008]
# 62062249295.8

# %% [markdown]
# # New Model

# %%
model=linear_model.
