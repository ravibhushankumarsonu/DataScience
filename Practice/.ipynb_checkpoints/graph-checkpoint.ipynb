# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

# %% [markdown]
#     Importing the neccessary library within to work with the ploting data.

# %%
Data=pd.read_csv('HR_comma_sep.csv')

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# sales                    14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
#     Main structer of the data-frame which gives the knowledge about the data and their staructure

# %%
Data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
catageries=['number_project','time_spend_company','Work_accident ','left']
len(Data)
# Out:
# 14999

# %%
x=np.linspace(0,14998,num=14999);
#plt.plot(x,data['statisfaction_level'])
#plt.show()
print(x)
# Out:
# [  0.00000000e+00   1.00000000e+00   2.00000000e+00 ...,   1.49960000e+04
#    1.49970000e+04   1.49980000e+04]

# %%
#print(data['satisfaction_level'])

# %%
#fig=plt.subplots(figsize=(40,10))
sns.countplot(x="number_project",data=Data)
plt.title("No. of employee")
plt.show()

# %% [markdown]
# Maximum number of employees did 4 projects.

# %%
sns.countplot(x='left',data=Data)
plt.title("No. of employee")
plt.show()

# %%
sns.countplot(x='time_spend_company',data=Data)
plt.title("No. of employee")
plt.show()

# %%
sns.countplot(x='Work_accident',data=Data)
plt.title("No. of employee")
plt.show()

# %%
sns.countplot(x='sales',data=Data)
plt.title("No. of employee")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='salary',data=Data)
plt.title("No. of employee")
#plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='salary',data=Data,hue='left')
plt.title("No. of employee")
#plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='number_project',data=Data,hue='salary')
plt.title("No. of employee")
#plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='time_spend_company',data=Data,hue='salary')
plt.title("No. of employee")
#plt.xticks(rotation=90)
plt.show()

# %%
corr=Data.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True,cbar=True,cmap="coolwarm")
plt.xticks(rotation=90)
plt.show()

# %%
Data.
